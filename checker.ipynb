# %%
import numpy as np

# 读取 .npy 文件
data = np.load('/mnt/vdb1/lyt/condition_pairs_test.npy', allow_pickle=True)

# 打印数据
print(data)
# Out:
# [{'scene': 'scene_2516_1535487802697042', 'real_img_path': '/mnt/vdc1/lyt/interpolation_results/scene_2516_1535487802697042/pos_110.jpg', 'real_angle': 110, 'cond_img_paths': ['/mnt/vdc1/lyt/interpolation_results/scene_2516_1535487802697042/pos_082.50.jpg', '/mnt/vdc1/lyt/interpolation_results/scene_2516_1535487802697042/pos_145.00.jpg'], 'Ks': [array([[800. ,   0. , 799.5],
#         [  0. , 800. , 449.5],
#         [  0. ,   0. ,   1. ]], dtype=float32), array([[800. ,   0. , 799.5],
#         [  0. , 800. , 449.5],
#         [  0. ,   0. ,   1. ]], dtype=float32)], 'Rs': [array([[ 0.8870108,  0.       , -0.4617486],
#         [ 0.       ,  1.       ,  0.       ],
#         [ 0.4617486,  0.       ,  0.8870108]], dtype=float32), array([[ 0.81915206,  0.        ,  0.57357645],
#         [ 0.        ,  1.        ,  0.        ],
#         [-0.57357645,  0.        ,  0.81915206]], dtype=float32)], 'cond_angles': [82.5, 145.0]}
# ...
